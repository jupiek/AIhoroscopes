# %% [markdown]
# ### Stage 1:
# Perform statistical parsing/tagging on a document in JSON format
#
# INPUTS: JSON doc for the text input
# OUTPUT: JSON format `ParsedGraf(id, sha1, graf)`

# %%
import pytextrank
import sys, os
import pandas as pd

path_stage0 = "dat/AI/"
path_stage1 = "o1.json"
doc_name = "horoscopes_results.csv"
count = 1
list_keyterm = [0]*840
value_keyterm = [0]*840
for filename in os.listdir(path_stage0):
    count +=1
    index = filename.replace(".json","")
    if index.isdigit():
        with open(path_stage1, 'w') as f:
            for graf in pytextrank.parse_doc(pytextrank.json_iter(path_stage0 + filename)):
                f.write("%s\n" % pytextrank.pretty_print(graf._asdict()))
                # to view output in this notebook
                #print(pytextrank.pretty_print(graf))
        path_stage1 = "o1.json"
        path_stage2 = "o2.json"

        graph, ranks = pytextrank.text_rank(path_stage1)
        pytextrank.render_ranks(graph, ranks)

        with open(path_stage2, 'w') as f:
            for rl in pytextrank.normalize_key_phrases(path_stage1, ranks):
                f.write("%s\n" % pytextrank.pretty_print(rl._asdict()))
                # to view output in this notebook
                #print(pytextrank.pretty_print(rl))

        path_stage1 = "o1.json"
        path_stage2 = "o2.json"
        path_stage3 = "o3.json"

        kernel = pytextrank.rank_kernel(path_stage2)

        with open(path_stage3, 'w') as f:
            for s in pytextrank.top_sentences(kernel, path_stage1):
                f.write(pytextrank.pretty_print(s._asdict()))
                f.write("\n")
                # to view output in this notebook
                #print(pytextrank.pretty_print(s._asdict()))

        path_stage2 = "o2.json"
        path_stage3 = "o3.json"

        phrases = ", ".join(set([p for p in pytextrank.limit_keyphrases(path_stage2, phrase_limit=20)]))
        sent_iter = sorted(pytextrank.limit_sentences(path_stage3, word_limit=150), key=lambda x: x[1])
        s = []

        for sent_text, idx in sent_iter:
            s.append(pytextrank.make_sentence(sent_text))

        graf_text = " ".join(s)
        phrase_list = phrases.split(",")
        if "something" in phrase_list and len(phrase_list) > 1:
            phrase_list.remove("something")
        k = phrase_list[0]
        value_keyterm[int(index)-1] = graf_text
        list_keyterm[int(index)-1] = k
    #print(phrases.split(",")[0])
    #print("**excerpts:** %s\n\n**keywords:** %s" % (graf_text, phrases,))

    #[print(p) for p in pytextrank.limit_keyphrases(path_stage2, phrase_limit=100)]
# Out:
# [RankedLexeme(text='status quo', rank=0.08863771252314476, ids=[32, 33], pos='np', count=1), RankedLexeme(text='previous tempers', rank=0.07967543643132731, ids=[27, 28], pos='np', count=1), RankedLexeme(text='right direction', rank=0.06635890820145629, ids=[8, 9], pos='np', count=1), RankedLexeme(text='people', rank=0.05495312669897455, ids=[20], pos='np', count=1), RankedLexeme(text='sign', rank=0.05296827948089249, ids=[22], pos='nn', count=1), RankedLexeme(text='born', rank=0.050831642375134496, ids=[21], pos='vbn', count=1), RankedLexeme(text='solve', rank=0.04938096543335022, ids=[29], pos='vb', count=1), RankedLexeme(text='quo', rank=0.04431885626157238, ids=[33], pos='nn', count=1), RankedLexeme(text='fact', rank=0.04168277579157445, ids=[19], pos='nn', count=1), RankedLexeme(text='steps', rank=0.03611711892841082, ids=[14], pos='np', count=1), RankedLexeme(text='stand', rank=0.035383922794039374, ids=[26], pos='vb', count=1), RankedLexeme(text='solutions', rank=0.03487254255
# ...

# %%
csv_input = pd.read_csv(doc_name)
csv_input['keyTerms'] = list_keyterm
csv_input['horoscope'] = value_keyterm
csv_input.to_csv("horoscope_processed.csv")
#print(list_keyterms)

# %%
csv_input
# Out:
#      Unnamed: 0      temp         sign day_of_week  \
# 0             0  0.841130        Aries      Monday
# 1             1  0.944679       Taurus      Monday
# 2             2  0.947067       Gemini      Monday
# 3             3  0.879236       Cancer      Monday
# 4             4  0.931235          Leo      Monday
# 5             5  0.840355        Virgo      Monday
# 6             6  0.821136        Libra      Monday
# 7             7  0.928270      Scorpio      Monday
# 8             8  0.929995  Sagittarius      Monday
# 9             9  0.919776    Capricorn      Monday
# 10           10  0.872465     Aquarius      Monday
# 11           11  0.835630       Pisces      Monday
# 12           12  0.996731        Aries     Tuesday
# 13           13  0.963213       Taurus     Tuesday
# 14           14  0.816453       Gemini     Tuesday
# 15           15  0.893895       Cancer     Tuesday
# 16           16  0.966766          Leo     Tuesday
# ...

# %%
path_stage0 = "dat/AI/1.json"
path_stage1 = "o1.json"

with open(path_stage1, 'w') as f:
    for graf in pytextrank.parse_doc(pytextrank.json_iter(path_stage0)):
        f.write("%s\n" % pytextrank.pretty_print(graf._asdict()))
        # to view output in this notebook
        #print(pytextrank.pretty_print(graf))

# %% [markdown]
# ### Stage 2:
# Collect and normalize the key phrases from a parsed document
#
# INPUTS: `<stage1>`
# OUTPUT: JSON format `RankedLexeme(text, rank, ids, pos)`

# %%
path_stage1 = "o1.json"
path_stage2 = "o2.json"

graph, ranks = pytextrank.text_rank(path_stage1)
pytextrank.render_ranks(graph, ranks)

with open(path_stage2, 'w') as f:
    for rl in pytextrank.normalize_key_phrases(path_stage1, ranks):
        f.write("%s\n" % pytextrank.pretty_print(rl._asdict()))
        # to view output in this notebook
        print(pytextrank.pretty_print(rl))
# Out:
# ["bit more time", 0.10134685910074866, [632, 24, 136], "np", 1]
# ["other person", 0.0827693023304082, [75, 54], "np", 1]
# ["certain scenario", 0.07950106040091366, [188, 636], "np", 1]
# ["accept", 0.07063166353512919, [11], "vb", 1]
# ["calculated one", 0.06727037143171731, [2481, 233], "np", 1]
# ["assistance", 0.06226243126696534, [380], "np", 1]
# ["making", 0.04804084701044293, [78], "vbg", 2]
# ["time", 0.046003989254963046, [136], "nn", 1]
# ["patience", 0.04482304637246345, [123], "nn", 1]
# ["others", 0.0413846511652041, [75], "np", 1]
# ["frustration", 0.040977624722790415, [480], "nn", 1]
# ["someone", 0.040785384536545004, [125], "np", 1]
# ["concern", 0.03808363563887839, [277], "nn", 1]
# ["state", 0.03645359905942687, [1154], "nn", 1]
# ["suggest", 0.0350099586424615, [220], "vb", 1]
# ["bit", 0.03406050783250591, [632], "nn", 1]
# ["putting", 0.029041860349459526, [172], "vbg", 1]
# ["scenario", 0.026886040954350612, [636], "nn", 1]
# ...

# %%
import networkx as nx
import pylab as plt

nx.draw(graph, with_labels=True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-3e690e6b5a71> in <module>
#       2 import pylab as plt
#       3
# ----> 4 nx.draw(graph, with_labels=True)
#       5 plt.show()
#
# ~/miniconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, hold, **kwds)
#     119
#     120  # allow callers to override the hold state by passing hold=True|False
# --> 121     b = plt.ishold()
#     122     h = kwds.pop('hold', None)
#     123     if h is not None:
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ishold'

# %% [markdown]
# ### Stage 3:
# Calculate a significance weight for each sentence, using MinHash to approximate a Jaccard distance from key phrases determined by TextRank
#
# INPUTS: `<stage1> <stage2>`
# OUTPUT: JSON format `SummarySent(dist, idx, text)`

# %%
path_stage1 = "o1.json"
path_stage2 = "o2.json"
path_stage3 = "o3.json"

kernel = pytextrank.rank_kernel(path_stage2)

with open(path_stage3, 'w') as f:
    for s in pytextrank.top_sentences(kernel, path_stage1):
        f.write(pytextrank.pretty_print(s._asdict()))
        f.write("\n")
        # to view output in this notebook
        print(pytextrank.pretty_print(s._asdict()))

# %% [markdown]
# ### Stage 4:
# Summarize a document based on most significant sentences and key phrases
#
# INPUTS: `<stage2> <stage3>`
# OUTPUT: Markdown format

# %%
path_stage2 = "o2.json"
path_stage3 = "o3.json"

phrases = ", ".join(set([p for p in pytextrank.limit_keyphrases(path_stage2, phrase_limit=15)]))
sent_iter = sorted(pytextrank.limit_sentences(path_stage3, word_limit=150), key=lambda x: x[1])
s = []

for sent_text, idx in sent_iter:
    s.append(pytextrank.make_sentence(sent_text))

graf_text = " ".join(s)
print("**excerpts:** %s\n\n**keywords:** %s" % (graf_text, phrases,))
# Out:
# [RankedLexeme(text='bit more time', rank=0.10134685910074866, ids=[632, 24, 136], pos='np', count=1), RankedLexeme(text='other person', rank=0.0827693023304082, ids=[75, 54], pos='np', count=1), RankedLexeme(text='certain scenario', rank=0.07950106040091366, ids=[188, 636], pos='np', count=1), RankedLexeme(text='accept', rank=0.07063166353512919, ids=[11], pos='vb', count=1), RankedLexeme(text='calculated one', rank=0.06727037143171731, ids=[2481, 233], pos='np', count=1), RankedLexeme(text='assistance', rank=0.06226243126696534, ids=[380], pos='np', count=1), RankedLexeme(text='making', rank=0.04804084701044293, ids=[78], pos='vbg', count=2), RankedLexeme(text='time', rank=0.046003989254963046, ids=[136], pos='nn', count=1), RankedLexeme(text='patience', rank=0.04482304637246345, ids=[123], pos='nn', count=1), RankedLexeme(text='others', rank=0.0413846511652041, ids=[75], pos='np', count=1), RankedLexeme(text='frustration', rank=0.040977624722790415, ids=[480], pos='nn', count=1), R
# ...
